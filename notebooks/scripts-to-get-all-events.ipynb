# %% [markdown]
# # Get the Competitions

# %%
from statsbombpy import sb
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')

# %%
comps = sb.competitions()
type(comps)
# Out:
# pandas.core.frame.DataFrame

# %%
competition_ids = []
season_ids = []
for i in range(len(comps)):
    competition_ids.append(comps.loc[i,"competition_id"])
    season_ids.append(comps.loc[i,"season_id"])

# %% [markdown]
# # Get Matches

# %%
match_ids = []
for c in range(len(competition_ids)):
    comp_id = competition_ids[c]
    seas_id = season_ids[c]
    matches = sb.matches(competition_id=comp_id,season_id=seas_id)
    for m in range(len(matches)):
        match_ids.append(matches.loc[m,"match_id"])

# %%
matches
# Out:
#     match_id  match_date      kick_off                        competition  \
# 0      22949  2019-06-12  18:00:00.000  International - Women's World Cup
# 1      22943  2019-06-11  21:00:00.000  International - Women's World Cup
# 2      22944  2019-06-11  18:00:00.000  International - Women's World Cup
# 3      22961  2019-06-14  15:00:00.000  International - Women's World Cup
# 4      22964  2019-06-15  15:00:00.000  International - Women's World Cup
# 5      68357  2019-06-22  21:00:00.000  International - Women's World Cup
# 6      22933  2019-06-09  13:00:00.000  International - Women's World Cup
# 7      22963  2019-06-14  18:00:00.000  International - Women's World Cup
# 8      68311  2019-06-18  21:00:00.000  International - Women's World Cup
# 9      22940  2019-06-10  18:00:00.000  International - Women's World Cup
# 10     22945  2019-06-12  15:00:00.000  International - Women's World Cup
# 11     22956  2019-06-13  21:00:00.000  International - Women's World Cup
# ...

# %%
len(match_ids)
# Out:
# 3316
